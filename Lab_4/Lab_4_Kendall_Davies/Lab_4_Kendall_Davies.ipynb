# %% [markdown]
# # Lab 4 Report:
# ## Create Arthur Conan Doyle AI with RNN

# %% [markdown]
# ### Name:

# %%
import numpy as np
import matplotlib.pyplot as plt
import torch
from torch.distributions import Categorical

# %%
from IPython.display import Image # For displaying images in colab jupyter cell

# %%
Image('lab4_exercise.png', width = 1000)

# %% [markdown]
# ## Prepare Data

# %%
# First n-characters to use for training
data_size_to_train = 50000

# Load the Shakespeare data up to data_size_to_train
data = open('sherlock.txt', 'r').read()[5000:5000+data_size_to_train]

# Find the unique characters within the training data
characters = sorted(list(set(data)))

# total number of characters in the training data and number of unique characters
data_size, vocab_size = len(data), len(characters)

print("Data has {} characters, {} unique".format(data_size, vocab_size))
# Out:
# Data has 50000 characters, 71 unique

# %%
# Use Python Dictionary to map the characters to numbers and vice versa

character_to_num = { ch:i for i,ch in enumerate(characters) }
num_to_character = { i:ch for i,ch in enumerate(characters) }

# %%
# Use the character_to_num dictionary to map each character in the training dataset to a number

data = list(data)

for i, ch in enumerate(data):
    data[i] = character_to_num[ch]

# %% [markdown]
# ## Define Model

# %%
class CharRNN(torch.nn.Module):
    
    def __init__(self, num_embeddings, embedding_dim, input_size, hidden_size, num_layers, output_size):
        
        super(CharRNN, self).__init__()
        
        # Define embedding layer
        # num_embeddings = number of unique characters
        # embedding_dim = size of a vector that encodes each character
        self.embedding = torch.nn.Embedding(num_embeddings, embedding_dim)
        
        # Define vanilla RNN cell
        # num_layers = Number of RNN cells to be stacked for deep-RNN
        # nonlinearity = Activation function to use
        self.rnn = torch.nn.RNN(input_size=input_size, hidden_size=hidden_size, 
                                num_layers=num_layers)
        
        # decoder layer that takes hidden states as inputs and output probabilities for each character
        # output_size = number of unique characters
        self.decoder = torch.nn.Linear(hidden_size, output_size)
    
    def forward(self, input_seq, hidden_state):
        
        # Forward pass input sequence to embedding layer 
        embedding = self.embedding(input_seq)
        
        # RNN cell takes output of embedding layer + previous hidden state as inputs
        output, hidden_state = self.rnn(embedding, hidden_state)
        
        # Forward pass the RNN cell output to decoder to get the probabilities
        output = self.decoder(output)
        
        # hidden states need to be detached from computation graph to be re-used as input
        return output, hidden_state.detach()

# %% [markdown]
# ## Define Hyperparameters

# %%
# Fix random seed
torch.manual_seed(25)

# Define RNN network
rnn = CharRNN(num_embeddings = vocab_size, embedding_dim = 10, 
              input_size = 10, hidden_size = 256, num_layers = 1,
              output_size = vocab_size)

# Define learning rate and epochs
learning_rate = 3e-4          
epochs = 50

# Size of the input sequence to be used during training and validation
# Note that too long input sequence can lead to unstable training via exploding/vanishing gradients
training_sequence_len = 150
validation_sequence_len = 200    

# Define loss function and optimizer
loss_fn = torch.nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(rnn.parameters(), lr=learning_rate)

# add .cuda() for GPU acceleration
#rnn.()

# %% [markdown]
# ## Identify Tracked Values

# %%
# Tracking training loss per each input/target sequence fwd/bwd pass
train_loss_list = []

# %% [markdown]
# ## Train Model

# %%
# Convert training data into torch tensor and make it into vertical orientation (N, 1)
# Attach .cuda() if using GPU
data = torch.unsqueeze(torch.tensor(data), dim = 1) #.cuda()

# Training Loop ----------------------------------------------------------------------------------------------------------

for epoch in range(epochs):
    
    # Randomly select a starting character from first 100 characters in training set
    character_loc = np.random.randint(100)
    
    # iteration number to keep track of until the sequence reaches the end of training data
    iteration = 0
    
    # initialize initial hiddens state as None
    hidden_state = None

    while character_loc + training_sequence_len + 1 < data_size: # loop continues until target_seq reaches end of the data
        
        # Define input/target sequence
        input_seq = data[character_loc : character_loc + training_sequence_len]
        target_seq = data[character_loc + 1 : character_loc + training_sequence_len + 1]
        
        # Pass input sequence and hidden_state to RNN
        output, hidden_state = rnn(input_seq, hidden_state)
        
        # Compute loss between RNN output sequence vs target sequence
        # torch.squeeze removes the column dimension and make them into horizontal orientation
        loss = loss_fn(torch.squeeze(output), torch.squeeze(target_seq))
        
        # Append loss
        train_loss_list.append(loss.item())
        
        # Empty gradient buffer -> backpropagation -> update network
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
        # Update starting character for next sequence
        character_loc += training_sequence_len
        
        # Update iteration number
        iteration += 1
            
    print("Averaged Training Loss for Epoch ", epoch,": ", np.mean(train_loss_list[-iteration:]))
    
    # Sample and generate a text sequence after every epoch --------------------------------------------------------------
    
    #Initialize character location and hidden state for validation
    character_loc = 0
    hidden_state = None
    
    # Pick a random character from the dataset as an initial input to RNN 
    rand_index = np.random.randint(data_size-1)
    input_seq = data[rand_index : rand_index+1]

    print("----------------------------------------")
    with torch.no_grad():
        
        while character_loc < validation_sequence_len: # Loop continues until RNN generated sequence is in desired length
            
            # Pass validation sequence to RNN
            # Note that RNN now uses its previous output character as input
            output, hidden_state = rnn(input_seq, hidden_state)
            
            # Take the softmax of the decoder output to get the probabilities of predicted characters
            output = torch.nn.functional.softmax(torch.squeeze(output), dim=0)
            # Use the  probabilities to sample the output character
            character_distribution = torch.distributions.Categorical(output)
            character_num = character_distribution.sample()
            
            # Convert the character number selected from sampling to actual character and print
            print(num_to_character[character_num.item()], end='')
            
            # Update the input_seq so that it's using the output of the RNN as new input
            input_seq[0][0] = character_num.item()
            
            # Update the character location 
            character_loc += 1

    print("\n----------------------------------------")
# Out:
# Averaged Training Loss for Epoch  0 :  3.013707586952874
# ----------------------------------------
# V-q-Gltr odKlmroHreoil .ild dQ id ia
# iciode atudo mirkfl dh dofet b n" th
#  dorh  tad  gremers 3hs Himy
# nn deannL aToed  hxep" aos oxt teiath bhU Pdon cene"at.oW " l
# b
#  Tato
#
# outinn t
# e
# g
# wralit afre
# ----------------------------------------
# Averaged Training Loss for Epoch  1 :  2.652308949479112
# ----------------------------------------
#  cp movt -v wanrechirtyt, brun
# . SHent b misaitkhis oity"
#
# U mth Cinninc Ho Hh sofhong Weelhing raaarefet fold, aud sthom te.hen"."
#
# "
#
#  Mot Aelled th
#  bol reap bicg at aac,his,v" b
# edewhm Kb whimeru
# ----------------------------------------
# Averaged Training Loss for Epoch  2 :  2.50249562421477
# ----------------------------------------
# PWou. go' hack the unsdeet -of buraede heh wnd reendoc auasivo-, eunl
# hic3ase dvoe fom 'Non ament he ad anreteon. Mfouliggc
#  intoeth,.
# e
#  "IIe and vves his as. Yek wssaod esa.unthingd  cirmishasiss
#
# ----------------------------------------
# Averaged Training Loss for Epoch  3 :  2.401392615951217
# ----------------------------------------
# eres'fet mell soid,'" he mainrotenC. TNmnndonping of harlaanmt
#
# "
#
#
# " WNit thile sousded Aton? "om ho' ond
#  caurlt ceonr, Iov so-fere. AIunle
#  anle andet ise and wha txist whb thrlrefol' wetthe Bu. th
# ----------------------------------------
# Averaged Training Loss for Epoch  4 :  2.32063271590026
# ----------------------------------------
# unmto
#  "o
#  are woawcencel bat lo
#  bpieg be mixpreud
#  wideej Wos' her as upth, Himgget tht dut tee sout  col raog btol
#
#  onbe, Iat the amereep"
#
#  2owll,."
#
# """ Whis sory uceleg vlvY himesoun, and out b
# ----------------------------------------
# Averaged Training Loss for Epoch  5 :  2.251270555519127
# ----------------------------------------
#  9ximputheasoz Ice chemeny
#  Hlsesedog chimes te byst breuden
#
#  senfery-b
#  be!ide mere toY sore il."
#
#  "Nt tre pist the com apcofthed "aotr inols. GithotaThet cas cnlmagee stouch, hisk ape."
#
#  "W
# ave '
# ----------------------------------------
# Averaged Training Loss for Epoch  6 :  2.2231478324855667
# ----------------------------------------
# d,"aI.
# " Shad zoxr and at patseretadl-thorp ou as thith
#  Iithurgee. 9 it teiningt
#  and ormuctit,"-r steen nd, ifand the lesdeles bforlowh I toravises ore in the mothen eot comegatelo,. The -obled m. D
# ----------------------------------------
# Averaged Training Loss for Epoch  7 :  2.1479905023947135
# ----------------------------------------
# e,
# "
#
#  "N Btiundor."
#
#  "Qre of the begked'
# . Th tuigh wirren in yhlae weageh,-ed
# , There conmen yod" Ce the dy olexunbed nad Rnone his urwecp-intod' ta was abe aot sermod wathing. OTthe out reac is co
# ----------------------------------------
# Averaged Training Loss for Epoch  8 :  2.1036756957869933
# ----------------------------------------
# Lond," Loo the reacled of whould Lheulfeed hian."
#
#  "Thik tivn
#  het sis ifre the wosks. Tit apathlred commec np mith and the lifingels
#  dithody nber intof'en.
#
#  Guntibkem, was ans nfedele fim. Weefer.
# ----------------------------------------
# Averaged Training Loss for Epoch  9 :  2.0638513033648573
# ----------------------------------------
# htokgensesstelly the datannens pounged in woifRasthis .o neetred. Pnd taod-,
#  tus fromsonk hy msoued somint. That theme pimin his aleb "irevsh hes."
#  "Thele dreedot Ra doster shomy owluntlr methcast s
# ----------------------------------------
# Averaged Training Loss for Epoch  10 :  2.0269704418010024
# ----------------------------------------
# ed-ringuraniloun boocg condedes. Yo perustaring atlor-and in avushed xogiit."
#
#  "At melidg serete upanlinus.
#
#  "Otrered ool acland and frapsan."-share fole sleats sermowathisp, bus to as hich lasten f
# ----------------------------------------
# Averaged Training Loss for Epoch  11 :  1.9926925771925823
# ----------------------------------------
# t"WY"Y Cas."
#
#  "Yo whourdeds!zon!, powreng it
# ont, comporfirn, mebe wusuariss, whale morgess, I. The, vyt coce. Gut to hthers; rether. Hhst sous,ed cat breed"
#  "I be mighson in that there, ale poady d
# ----------------------------------------
# Averaged Training Loss for Epoch  12 :  1.960558186453509
# ----------------------------------------
# x? do to the htlang hoags ale here halnn-urevuay tuid a
#
#  Mthol
#  byovee of and kolenss has.""
#  A
#  ethres? Iuehed at san upqn the Awfinging
#  urang, peist.
#
#
#  "I
#  what anxoneed, you hur storfonved as jo
# ----------------------------------------
# Averaged Training Loss for Epoch  13 :  1.9299079444673326
# ----------------------------------------
# 5 gwexy to my a lovift. "Ay the sit befory.
#
#
#  gilsere Greg that the
#  toltaly olnn stanocc yherpace sack
#  nyttit? It inaly sregton thesr of uppain tore rulk nof
#  int
#  ablowady or. Itarewionod but a fo
# ----------------------------------------
# Averaged Training Loss for Epoch  14 :  1.901563463984309
# ----------------------------------------
# hrig
#  afder at the knowes
#  nolaucant ins nother
# . They lat''t. I
#  cempar,."
#
#  "Ye dayer mirecssnfend."
#
#  "He heme peryted an feclor Aat reavny, ondy thongleg
#  his
#  stidpall.
#
#  " had the eximbatent
#  he
# ----------------------------------------
# Averaged Training Loss for Epoch  15 :  1.874234198807954
# ----------------------------------------
# ns heradclunt bur are ancuritian of I
#  matacky Halper campzed couming
#  cimchaafy, ye apcertening fordoss Gud they in murtain to the lotick
#  restarted is sberiod Guey mortoca ching arl beer
#  into that
# ----------------------------------------
# Averaged Training Loss for Epoch  16 :  1.8491502802774131
# ----------------------------------------
# dRarly, and
#  chatinus at is monfaniage to the Ppent, counds ares. He seed Sof, for the ducjhers."
#
#  "You hrastict.
#
#  "IW was ng there veat wurked info
#  the wile an Gied with the main evering. "Othich
# ----------------------------------------
# Averaged Training Loss for Epoch  17 :  1.8240640411175877
# ----------------------------------------
# wxmpemble blense that the sigkle
#
#  enchtion is sulms
#  overaury spe?" he caser,
#  rescased at Msoutale, bus to me couby oun with atherace was unper, gid ont Soomtond the perviced at ytere walk. Mn tos.
# ----------------------------------------
# Averaged Training Loss for Epoch  18 :  1.8005120976861702
# ----------------------------------------
# n gatherd
#  or," I blood non the brandee, and stacing by whemy
#  Iuben fhopid atereod uleer.
#
#  "Qm Joard, Git It would d3or de the
#  here gct-chisaar, cormive unon rempations heed undolloficg moder disue
# ----------------------------------------
# Averaged Training Loss for Epoch  19 :  1.7783124967511879
# ----------------------------------------
# xow" heiva
#  of!."
#
#  "He boim, thicl tiade," sied
#  strope ferlot," sit. Jo mowerede wiran foranther aresiciln which was threes, Rurdurald sert for hadis, .o
#  owht-what thes. Stheat, and lefele 'oon qa
# ----------------------------------------
# Averaged Training Loss for Epoch  20 :  1.7556898815853819
# ----------------------------------------
# -hur destory."
#
#  "Ar so stured
#  bauld upraate. Gus heams, byto he. Pureater there houss
#  which him," he a dadfairs bight said and uneer. deiling have qhick ras ener heed son there,, at
#  Sound.
#  hevely
# ----------------------------------------
# Averaged Training Loss for Epoch  21 :  1.7348548156005126
# ----------------------------------------
# mCdlogk suld oter
#  to be sterm, weich peaned obes, well
#  abers as beser, and I wattand flagary to mashing. "Thewiek the notting it sim," I asshrredd bat langsion ont I have a xrixtich in the bowaronco
# ----------------------------------------
# Averaged Training Loss for Epoch  22 :  1.7147625154919095
# ----------------------------------------
# d. Dvery having of a longing-riages hingld.
#
#  2herloyc I anden the gtor. Ge and paze to dextrod, and nspingly fare, undenced, and is plopening all the rustswed the Sopes. Hus exameet, In
#  stoid,
#  with
# ----------------------------------------
# Averaged Training Loss for Epoch  23 :  1.695748648370605
# ----------------------------------------
# hun-Caxros beat mare the conkacheps aponected. "Than go inen overinh abautled it on marnved anel of By his fenjot,, bleor," IHereanc, whish tThe gee, which hate appearty
#  pornowl moshed
#  a wath is ubl
# ----------------------------------------
# Averaged Training Loss for Epoch  24 :  1.6766918531383377
# ----------------------------------------
# humu?y-um a fon wouth
#  Sound," hat saverning the mass of Limq-one wo detinger a fandowuss mextais eace and chord coln shicing bace leftrewsien in the nonutines.
#
#  "Fe'gen."
#
#  "Therected comanchuning h
# ----------------------------------------
# Averaged Training Loss for Epoch  25 :  1.6585473942469402
# ----------------------------------------
#
#  1Tthe? Oteredy
#  tonth strmigh, tathen
#  and twent that
#  gat lowg iftors, buched sountedor. "Nser. So amavereed abcerds. These mesttred times ole hands, and ammiots as ever not reasing my spot the nci
# ----------------------------------------
# Averaged Training Loss for Epoch  26 :  1.640255320143987
# ----------------------------------------
# x;-thought
#  remorked hand simplecaed then han.,"
#
#  "Le, Sowartier, gustledfe
#  read, gunded witis asmoksh daid aptecstormed to mad Ier hilds his. He def ofayife, "him hands and couth hards to me for te
# ----------------------------------------
# Averaged Training Loss for Epoch  27 :  1.6230228370930775
# ----------------------------------------
# nkt'
#  unreurted;."
#
#  "To these," feraben of
#  not, bus kelngred to mat be an entrupen.
#
#  "Nerut no doubse, with rade n
#  the reasest
#  divicked."
#
#  "Haced in Avely
# ; that tis andly betinged, and helm cur
# ----------------------------------------
# Averaged Training Loss for Epoch  28 :  1.6058099975099076
# ----------------------------------------
# xtance.
#
#  Y" I
#  an headly detver then the yaid
#  not bet at had bean inqeactem men coustusine, parked abprepal, vangly," "How deiva
#  remery that yoe begt a man not
#  'sen for the there, there exyte. -Nr
# ----------------------------------------
# Averaged Training Loss for Epoch  29 :  1.5893821669770434
# ----------------------------------------
# ch; aduy onen-aI inenges.
#
#  "You exprait! ond go kn,
#  studen out whet," What and have anver optering, and to repmimed in strade lain. No myot nothing ot bild-recs a fan's ort moor, pin wead which, ros
# ----------------------------------------
# Averaged Training Loss for Epoch  30 :  1.573295977819397
# ----------------------------------------
# his," hapeln, glor. Sherlesk abress, the nace bley and chring-sted, beiny Souss,
#  my dose. Gnaingy te his tall-n to the rexon.
#
#  "her vedy not nathon."
#
#  Ho mpean," should.
#
#  "Nour, and hen lray youth
# ----------------------------------------
# Averaged Training Loss for Epoch  31 :  1.5572209716201186
# ----------------------------------------
# 4s qapen way
#  edery-sorm," he said herpsind to sed food not ofer have
#  soidatly doty this," seave were sposs Sam stall mathen of-umustsering to lasy on Atn mysers, shorven aco, ching,
#  me expreftiyl w
# ----------------------------------------
# Averaged Training Loss for Epoch  32 :  1.5413884050156696
# ----------------------------------------
# xved; have to me medace the untaning,
#  thet whoules.
#
#
# ed
#  stalined ot of have harchirn--you gyieg ape at mavion. Thaved byen a tind him."
#
#  "These hease, gured times ut.o
#
#  Sangswed in myhern
#  praac
# ----------------------------------------
# Averaged Training Loss for Epoch  33 :  1.5255524854402285
# ----------------------------------------
# ng
#
#  tCind was
#  ray wapce," "Nosted
#  wonlert's there hands with a relartic at whome firewions he had to coq, nocking
#  the vail?"
#
#  Ivay amysone and haided the litn the fould
#  clats, the
#  Mpterthen of
# ----------------------------------------
# Averaged Training Loss for Epoch  34 :  1.5103827747138772
# ----------------------------------------
# d. I
#  face awyive, I was conclancest hime oneqhory very appectaty tobreg ston, pourds lyig
#  would exasped upon the obper sour examps; in and
#  ones exoukh. "It
#  he spall.."
#
#  "You have mancon
#  out and
# ----------------------------------------
# Averaged Training Loss for Epoch  35 :  1.4952006519558918
# ----------------------------------------
#  INo. wollen sifartasiant.
#
#  "Wo pismencl you arkicud afterminill. Were to bols id the
#  with ivence
#  event Gis."
#
#  "If was bulded upon the lanes of some
#  loce for deen be a gight.-Fabare amanforms.
#  8
# ----------------------------------------
# Averaged Training Loss for Epoch  36 :  1.4800485537712833
# ----------------------------------------
# clong, there will evre to shend ont ppreaunded of mes,ot ho Jould hic, I hugled sonth foc mys, thet is of the mad sore of are loung, the werl mad streld enduet. Wo apquned up.eed a puriles
#  uere,s and
# ----------------------------------------
# Averaged Training Loss for Epoch  37 :  1.4653497162353561
# ----------------------------------------
# xxordaning enthis dosted at the beibe, of the made over and tour. Comerbord of my nexteand-tiod incurcons. Oherears. On accounced is the beoke, his pressed. "Wereghon-paty."
#
#  "As a cradfolding in tha
# ----------------------------------------
# Averaged Training Loss for Epoch  38 :  1.4503011735709939
# ----------------------------------------
# nd
#  roons to hir?"
#
#  "We tipd my maging cprened oft which he sand than I hole gad man had sklence fort curts-yed. Noussing to New gate fartanth.
#  St1it his realgh! us which melnem oot of sonmy which h
# ----------------------------------------
# Averaged Training Loss for Epoch  39 :  1.4360624082811602
# ----------------------------------------
# OPromevies. You eep, cordaction is the toore."
#
#   his eartano. Gm spowly houged the pitet itless
#  and fos swe pors, and of the
#
#  centuind to me wo unrening word."
#
#  "Nother not beloce Holses,of, Wowde
# ----------------------------------------
# Averaged Training Loss for Epoch  40 :  1.4216099644566442
# ----------------------------------------
# xtoy Erepicate, you that that I loud, is the
#  sarvens,
#  his resanthes of the beabess he, Bit of clood, his follured. Ot y tad not his into to take atquntedes
#  leavurys, the forlygser and mishence dasy
# ----------------------------------------
# Averaged Training Loss for Epoch  41 :  1.4076033343781937
# ----------------------------------------
#  sim."
#
#  "It his
#  pecpitiond were not a decond forted his tour enanger
#  atter?--this no conops of etere,. It you a grent chervoy-op, and. Woshredguty the work fal
#  thin wild had heald gan lants. There
# ----------------------------------------

# %% [markdown]
# ## Visualize & Evaluate Model

# %%
# Print a validation text sequence that most closely resembles Sherlock Holmes style to your liking

# %%
# Import seaborn for prettier plot
import seaborn as sns

sns.set(style = 'whitegrid', font_scale = 2.5)

# %%
# Plot the training loss and rolling mean training loss with respect to iterations
# Feel free to change the window size
plt.figure(figsize = (15, 9))

plt.plot(train_loss_list, linewidth = 3, label = 'Training Loss')
plt.plot(np.convolve(train_loss_list, np.ones(100), 'valid') / 100, 
         linewidth = 3, label = 'Rolling Averaged Training Loss')
plt.ylabel("training loss")
plt.xlabel("Iterations")
plt.legend()
sns.despine()

# %%
# Question: Which hyperparameters affect the quality of the generated text the most? Describe your answer below based on the training procedure
# you implemented for this assignment

# Answer:
